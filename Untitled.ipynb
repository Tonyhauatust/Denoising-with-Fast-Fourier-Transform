# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=[16,12]
plt.rcParams.update({'font.size':18})

##Creating a simple signal with two sine wave frequencies and a signal mixed with random noises
dt = 0.001 ##Interval between two consecutive sampling points is 0.001 second
t=np.arange(0,1,dt) ##An array of 1 second with size equal to 1/0.001
f=np.sin(2*np.pi*50*t)+np.sin(2*np.pi*120*t) ##A combination of 2 sine waves with frequencies 50 Hertz and 120 Hertz
f_clean= f
f = f + 2.5*np.random.randn(len(t)) ## The two sine waves mixed with random noises with magnitude from -2.5 to 2.5
plt.plot(t,f,color='c', LineWidth=1.5, label='Noisy')
plt.plot(t,f_clean,color='k',LineWidth=2,label='Clean')
plt.xlim(t[0],t[-1])
plt.xlabel("Time (second)")
plt.ylabel("Signal magnitude")
plt.
plt.legend()
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_13444/1432532329.py:13: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f,color='c', LineWidth=1.5, label='Noisy')
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_13444/1432532329.py:14: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f_clean,color='k',LineWidth=2,label='Clean')

# %%
## Transforming time domain of signal into frequency domain
fhat = np.fft.fft(f,n) # Applying Fast Fourier Transform to the signal with random noise(in time domain)
PSD = fhat*np.conj(fhat)/n
freq=(1/(dt*n))*np.arange(n)
L= np.arange(1,np.floor(n/2),dtype='int')
fig,axs = plt.subplots(2,1)
plt.sca(axs[0])
plt.plot(t,f,color='c',LineWidth=1.5,label='Noisy')
plt.plot(t,f_clean,color='k',LineWidth=2,label='Clean')
plt.xlim(t[0],t[-1])
plt.legend()

plt.sca(axs[1])
plt.plot(freq[L],PSD[L], color='c', LineWidth =2, label = 'Noisy')
plt.xlim(L[0],L[-1])
plt.legend()
plt.show()
# Out:
# 1.0
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_6764/2859621624.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f,color='c',LineWidth=1.5,label='Noisy')
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_6764/2859621624.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f_clean,color='k',LineWidth=2,label='Clean')
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_6764/2859621624.py:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(freq[L],PSD[L], color='c', LineWidth =2, label = 'Noisy')
# C:\Users\ASUS\AppData\Roaming\Python\Python38\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
for i in range(len(PSD)):
    if PSD[i] <100:
        PSD[i] ==0
        fhat[i]==0

ffilt = np.fft.ifft(fhat)

# %%
fig, axs = plt.subplots(3,1)

plt.sca(axs[0])
plt.plot(t,f,color='c', LineWidth = 1.5, label = 'Noisy')
plt.plot(t,f_clean,color = 'k', LineWidth =2, label = 'Clean')
plt.xlim(t[0],t[-1])
plt.legend()

plt.sca(axs[1])
plt.plot(t,ffilt,color='k', LineWidth =2, label ='Filtered')
plt.xlim(t[0],t[-1])
plt.legend()

plt.sca(axs[2])
plt.plot(freq[L],PSD[L],color = 'c', LineWidth=2, label = 'Noisy')
plt.plot(freq[L],PSDclean[L], color ='k', LineWidth = 1.5, label ='Filtered')
plt.xlim(freq[L[0]], freq[L[-1]])
plt.legend()

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_6764/1442806740.py:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f,color='c', LineWidth = 1.5, label = 'Noisy')
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_6764/1442806740.py:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,f_clean,color = 'k', LineWidth =2, label = 'Clean')
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_6764/1442806740.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(t,ffilt,color='k', LineWidth =2, label ='Filtered')
# C:\Users\ASUS\AppData\Roaming\Python\Python38\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_6764/1442806740.py:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(freq[L],PSD[L],color = 'c', LineWidth=2, label = 'Noisy')
# C:\Users\ASUS\AppData\Roaming\Python\Python38\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_6764/1442806740.py:16: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(freq[L],PSDclean[L], color ='k', LineWidth = 1.5, label ='Filtered')
# C:\Users\ASUS\AppData\Roaming\Python\Python38\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
## Hello Hello Hello Hello Hello Hello
